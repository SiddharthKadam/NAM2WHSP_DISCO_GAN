# %% [markdown]
# # Importing Required Modules

# %%
import os
import numpy as np
import librosa
import joblib
import matplotlib.pyplot as plt

# %% [markdown]
# # Extract MFCC

# %%
# Method to do padding 
def pad_audio(y, max_samples=1589449):
    padding_length = max_samples - len(y)
    if padding_length > 0:
        y = np.pad(y, (0, padding_length), 'constant')
    return y

# Method to extract MFCC 

def extract_mfcc(directory_path,audio_type,n_mfcc=13):
    # directory: The path to the directory containing the .wav files.
    # audio_type: Type of audio file NAM\WHSP
    # n_mfcc: The number of MFCCs to extract from each audio file (default is 13).  
    
    file_end="_"+str(audio_type)+".wav"  # _nam.wav / _headset.wav
    mfcc_features=[] # This will Store the Extracted mfcc Features for All Audio File 
    
    count = 0
    for filename in os.listdir(directory_path):
        if filename.endswith(file_end):
            count+=1
            # Construct the full path directory + File Name 
            file_path = os.path.join(directory_path, filename) 
            # 'librosa.load'  loads the audio file, returning the audio time series (y) and the sampling rate (sr)
            signal,sr=librosa.load(file_path, sr=None)
            signal=pad_audio(signal)
            # Computes the MFCCs of the audio signal. MFCCs are a representation of the short-term power spectrum of sound.
            mfccs = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=n_mfcc).flatten()
            # MFCC Shape 13 co-effictent* 3105  time steps
            # The mean of the MFCCs is calculated along the time axis and appended to the features list.
            # mfcc_features.append(np.mean(mfccs.T, axis=0))
            mfcc_features.append(mfccs)
            print("Extracting Feature : ",filename,"Mfcc_size:",mfccs.shape)
    mfcc_features = np.array(mfcc_features)
    print("Total Files Processed : ",count)
    print("Total MFCC Extracted ",len(mfcc_features))
    
    output_path=r"C:\Users\SID\Documents\Speech\voice_conversion_gan\data\processed\mfcc_"+str(audio_type)+".pkl"
    joblib.dump(mfcc_features, output_path)
    print(f'Features saved to {output_path}')

def make_equal_length(mfcc_features):
    max_len=0
    for mfcc in mfcc_features:
        if len(mfcc)>max_len:
            max_len=len(mfcc)
    return max_len

# %%
directory_path=r"C:\Users\SID\Documents\Speech\voice_conversion_gan\data\raw"
audio_type="nam"
# Extract Nam MFCC Features 
extract_mfcc(directory_path,audio_type)
# Out:
# Extracting Feature :  001_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  002_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  003_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  004_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  005_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  006_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  007_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  008_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  009_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  010_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  011_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  012_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  013_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  014_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  015_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  016_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  017_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  018_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  019_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  020_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  021_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  022_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  023_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  024_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  025_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  026_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  027_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  028_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  029_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  030_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  031_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  032_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  033_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  034_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  035_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  036_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  037_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  038_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  039_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  040_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  041_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  042_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  043_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  044_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  045_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  046_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  047_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  048_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  049_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  050_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  051_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  052_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  053_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  054_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  055_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  056_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  057_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  058_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  059_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  060_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  061_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  062_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  063_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  064_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  065_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  066_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  067_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  068_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  069_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  070_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  071_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  072_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  073_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  074_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  075_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  076_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  077_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  078_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  079_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  080_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  081_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  082_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  083_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  084_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  085_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  086_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  087_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  088_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  089_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  090_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  091_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  092_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  093_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  094_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  095_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  096_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  097_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  098_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  099_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  100_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  101_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  102_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  103_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  104_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  105_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  106_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  107_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  108_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  109_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  110_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  111_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  112_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  113_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  114_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  115_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  116_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  117_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  118_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  119_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  120_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  121_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  122_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  123_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  124_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  125_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  126_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  127_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  128_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  129_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  130_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  131_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  132_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  133_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  134_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  135_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  136_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  137_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  138_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  139_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  140_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  141_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  142_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  143_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  144_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  145_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  146_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  147_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  148_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  149_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  150_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  151_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  152_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  153_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  154_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  155_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  156_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  157_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  158_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  159_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  160_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  161_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  162_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  163_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  164_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  165_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  166_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  167_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  168_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  169_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  170_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  171_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  172_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  173_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  174_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  175_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  176_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  177_nam.wav Mfcc_size: (40365,)
# Extracting Feature :  178_nam.wav Mfcc_size: (40365,)
# Extracting Feature :